# %% [markdown]
# <a href="https://colab.research.google.com/github/sky16k/pyda/blob/main/pyda_basics_HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Домашнее задание к лекции "Основы Python"

# %% [markdown]
# ##Задание 1
# Даны 2 переменных, в которых хранятся строки произвольной длины: phrase_1 и phrase_2.
# Напишите код, который проверяет какая из этих строк длиннее.
#
# ###Примеры работы программы:
#
# phrase_1 = 'Насколько проще было бы писать программы, если бы не заказчики'
#
# phrase_2 = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'
#
# Результат:
# Фраза 1 длиннее фразы 2
#
# phrase_1 = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'
#
# phrase_2 = 'Насколько проще было бы писать программы, если бы не заказчики'
#
# Результат:
# Фраза 2 длиннее фразы 1
#
# phrase_1 = 'Насколько проще было бы писать программы, если бы не заказчики'
#
# phrase_2 = 'Насколько проще было бы писать программы, если бы не заказчики'
#
# Результат:
# Фразы равной длины
#
# ##Задание 2
# Дана переменная, в которой хранится число (год). Необходимо написать программу, которая выведет, является ли данный год високосным или обычным.
#
# ###Пример работы программы:
#
# year = 2020
# Результат:
# Високосный год
#
# year = 2019
# Результат:
# Обычный год
#
# ##Задание 3
# Необходимо написать программу, которая будет запрашивать у пользователя месяц и дату рождения и выводить соответствующий знак зодиака.
#
# ###Пример работы программы:
#
# Введите день:
# 30
#
# Введите месяц:
# Август
#
# Результат:
# Ваш знак зодиака: Дева
#
# Введите день:
# 29
#
# Введите месяц:
# Октябрь
#
# Результат:
# Ваш знак зодиака: Скорпион
#
# ##Задание 4
# Вам нужно написать программу для подбора упаковок по размерам товара. Размеры (ширина, длина, высота) хранятся в переменных (в сантиметрах):
#
# ###Используйте следующие правила:
#
# - если каждое из трех измерений менее или равно 15 сантиметрам, то выведите на экран "Коробка №1";
# - если хотя бы одно из измерений больше 15 сантиметров, но менее 50 сантиметров, то выводите "Коробка №2";
# - если длина товара больше 2 метров, то выводите "Упаковка для лыж";
# - во всех остальных случаях выводите "Стандартная коробка №3".
# ###Пример работы программы:
#
# width = 15
# length = 50
# height = 15
#
# Результат:
# Стандартная коробка №3
#
# width = 45
# length = 205
# height = 45
#
# Результат:
# Ищите упаковку для лыж
#
# ##Задание 5 (необязательное)
# Дана переменная, в которой хранится шестизначное число (номер проездного билета). Напишите программу, которая будет определять, является ли данный билет "счастливым". Билет считается счастливым, если сумма первых трех цифр совпадает с суммой последних трех цифр номера.
#
# ###Примеры работы программы:
#
# number = 123456
#
# Результат:
# Несчастливый билет
#
# number = 123321
#
# Результат:
# Счастливый билет
#
# ##Задание 6 (необязательное)
# Напишите программу, которая сможет вычислять площади трех фигур (круг, треугольник и прямоугольник). Тип фигуры запрашиваем через пользовательский ввод, после чего делаем запрос характеристик фигуры:
#
# - если пользователь выбрал круг, запрашиваем его радиус,
# - если треугольник – длины трех его сторон;
# - если прямоугольник – длины двух его сторон.
# ###Пример работы программы:
#
# Введите тип фигуры:
# Круг
#
# Введите радиус круга:
# 10
#
# Результат:
# Площадь круга: 314.16
#
# Введите тип фигуры:
# Треугольник
#
# Введите длину стороны A:
# 2
#
# Введите длину стороны B:
# 2
#
# Введите длину стороны C:
# 3
#
# Результат:
# Площадь треугольника: 1.98
#
# #ПРИМЕЧАНИЕ
# Домашнее задание сдается ссылкой Google Colab. Не сможем проверить или помочь, если вы пришлете:
#
# - файлы;
# - архивы;
# - скриншоты кода.
#
# Все обсуждения и консультации по выполнению домашнего задания ведутся только на соответствующем канале в slack.
#
# ##Как правильно задавать вопросы аспирантам, преподавателям и коллегам
# Прежде чем задать вопрос, попробуйте найти ответ в интернете. Навык самостоятельного поиска информации — один из важнейших. Каждый практикующий специалист любого уровня делает это ежедневно.
#
# ###Сформулируйте вопрос по алгоритму:
# 1. Что я делаю?
# 2. Какого результата я ожидаю?
# 3. Как фактический результат отличается от ожидаемого?
# 4. Что я уже попробовал сделать, чтобы исправить проблему?
#
# По возможности прикрепите к вопросу скриншоты либо ссылки на код. Не выкладывайте все решение, оставляйте только проблемный и воспроизводимый участок кода.

# %% [markdown]
# #Задание 1

# %%
'''
Задание 1
Даны 2 переменных, в которых хранятся строки произвольной длины: 
phrase_1 и phrase_2. 
Напишите код, который проверяет какая из этих строк длиннее.
'''

#phrase_2 = 'Насколько проще было бы писать программы, если бы не заказчики'
phrase_1 = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'
phrase_2 = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'


if len(phrase_1) > len(phrase_2): 
   print('Фраза 1 длиннее фразы 2')
elif len(phrase_1) < len(phrase_2):
   print('Фраза 2 длиннее фразы 1')
else :
   print('Фразы равной длины')
# Out:
# Фразы равной длины

# %% [markdown]
# #Задание 2

# %%
'''
Задание 2
Дана переменная, в которой хранится число (год). 
Необходимо написать программу, которая выведет, 
является ли данный год високосным или обычным.
'''
'''
високосным оставался год, номер которого кратен четырём, 
но исключение делалось для тех, которые были кратны 100. 
Такие годы были високосными только тогда, когда делились ещё и на 400
Т.е.в соответствии с григорианским календарем, год является високосным, 
если его номер кратен 4, но не кратен 100, а также если он кратен 400
'''

year = 2021
if (year%4==0 and (year%100!=0 or year%400==0) ) :
     print('Високосный год')
else :
     print('Обычный год')

'''
и вот тут вопрос: а не будет ли эффективнее 
не забивать все условия в одну проверку, 
а сделать сначала проверку на %4 отдельным if, 
как отсекающую большинство неподходящих вариантов, 
а уже затем проверять особенные случаи?
'''
# Out:
# Обычный год
# '\nи вот тут вопрос: а не будет ли эффективнее \nне забивать все условия в одну проверку, \nа сделать сначала проверку на %4 отдельным if, \nкак отсекающую большинство неподходящих вариантов, \nа уже затем проверять особенные случаи?\n'

# %% [markdown]
# #Задание 3

# %%
'''
Задание 3
Необходимо написать программу, которая будет запрашивать у пользователя 
месяц и дату рождения и выводить соответствующий знак зодиака.
'''

'''
Таблица знаков зодиака по числам
Овен: 21 марта — 20 апреля
Телец: 21 апреля — 21 мая
Близнецы: 22 мая — 21 июня
Рак: 22 июня — 22 июля
Лев: 23 июля — 21 августа
Дева: 22 августа — 23 сентября
Весы: 24 сентября — 23 октября
Скорпион: 24 октября — 22 ноября
Стрелец: 23 ноября — 22 декабря
Козерог: 23 декабря — 20 января
Водолей: 21 января — 19 февраля
Рыбы: 20 февраля — 20 марта
'''


mon = str.lower(input('Введите месяц рождения: '))
day = int(input('Введите дату рождения: '))
znak= 0

if mon == 'январь':
   if 1<=day<=20: znak = 'козерог'
   elif 21<=day<=31: znak = 'водолей'
   else: znak = 'error day'
elif mon == 'февраль':
   if 1<=day<=19: znak = 'водолей'
   elif 20<=day<=29: znak = 'рыбы'
   else: znak = 'error day'
elif mon == 'март':
   if 1<=day<=20: znak = 'рыбы'
   elif 21<=day<=31: znak = 'овен'
   else: znak = 'error day'
elif mon == 'апрель':
   if 1<=day<=20: znak = 'овен'
   elif 21<=day<=31: znak = 'телец'
   else: znak = 'error day'
elif mon == 'май':
   if 1<=day<=20: znak = 'телец'
   elif 21<=day<=31: znak = 'близнецы'
   else: znak = 'error day'
elif mon == 'июнь':
   if 1<=day<=20: znak = 'близнецы'
   elif 21<=day<=31: znak = 'рак'
   else: znak = 'error day'
elif mon == 'июль':
   if 1<=day<=20: znak = 'рак'
   elif 21<=day<=31: znak = 'лев'
   else: znak = 'error day'
elif mon == 'август':
   if 1<=day<=20: znak = 'лев'
   elif 21<=day<=31: znak = 'дева'
   else: znak = 'error day'
elif mon == 'сентябрь':
   if 1<=day<=20: znak = 'дева'
   elif 21<=day<=31: znak = 'весы'
   else: znak = 'error day'
elif mon == 'октябрь':
   if 1<=day<=20: znak = 'весы'
   elif 21<=day<=31: znak = 'скорпион'
   else: znak = 'error day'
elif mon == 'ноябрь':
   if 1<=day<=20: znak = 'скорпион'
   elif 21<=day<=31: znak = 'стрелец'
   else: znak = 'error day'
elif mon == 'декабрь':
   if 1<=day<=20: znak = 'стрелец'
   elif 21<=day<=31: znak = 'козерог'
   else: znak = 'error day'
else : znak = 'error month'

if znak == 'error month' :
   print('ошибка ввода месяца')
elif znak == 'error day' :
   print('ошибка ввода дня')
else :
   print(f'Ваш знак зодиака:',str.capitalize(znak))
# Out:
# Введите месяц рождения: март
# Введите дату рождения: 27
# Ваш знак зодиака: Овен

# %%
months = ['январь', 'февраль', 'март', 'апрель', 'май', 'июнь', 'июль', 'август', 'сентябрь', 'октябрь', 'ноябрь', 'декабрь']
days = range(1,32)

def zodiak(mon,day) :

  if mon == 'январь':
     if 1<=day<=20: znak = 10
     elif 21<=day<=31: znak = 11
     else: znak = 13
  elif mon == 'февраль':
     if 1<=day<=19: znak = 11
     elif 20<=day<=29: znak = 12
     else: znak = 13
  elif mon == 'март':
     if 1<=day<=20: znak = 12
     elif 21<=day<=31: znak = 1
     else: znak = 13
  elif mon == 'апрель':
     if 1<=day<=20: znak = 1
     elif 21<=day<=30: znak = 2
     else: znak = 13
  elif mon == 'май':
     if 1<=day<=20: znak = 2
     elif 21<=day<=31: znak = 3
     else: znak = 13
  elif mon == 'июнь':
     if 1<=day<=20: znak = 3
     elif 21<=day<=30: znak = 4
     else: znak = 13
  elif mon == 'июль':
     if 1<=day<=20: znak = 4
     elif 21<=day<=31: znak = 5
     else: znak = 13
  elif mon == 'август':
     if 1<=day<=20: znak = 5
     elif 21<=day<=31: znak = 6
     else: znak = 13
  elif mon == 'сентябрь':
     if 1<=day<=20: znak = 6
     elif 21<=day<=30: znak = 7
     else: znak = 13
  elif mon == 'октябрь':
     if 1<=day<=20: znak = 7
     elif 21<=day<=31: znak = 8
     else: znak = 13
  elif mon == 'ноябрь':
     if 1<=day<=20: znak = 8
     elif 21<=day<=30: znak = 9
     else: znak = 13
  elif mon == 'декабрь':
     if 1<=day<=20: znak = 9
     elif 21<=day<=31: znak = 10
     else: znak = 13
  else : znak = 0

  return {
        znak <= 0 : 'ошибка ввода месяца', #'ошибка ввода дня'
        1 == znak : 'Овен',
        2 == znak : 'Телец',
        3 == znak : 'Близнецы',
        4 == znak : 'Рак',
        5 == znak : 'Лев',
        6 == znak : 'Дева',
        7 == znak : 'Весы',
        8 == znak : 'Скорпион',
        9 == znak : 'Стрелец',
        10== znak : 'Козерог',
        11== znak : 'Водолей',
        12== znak : 'Рыбы',
        13<= znak : 'ошибка ввода дня'
  }[True]

m = str.lower(input('Введите месяц рождения: '))
d = int(input('Введите дату рождения: '))

z = zodiak(m,d)

if 'ошибка' in z: 
   print(z)
else: 
   print('Ваш знак зодиака: ',z)

'''
 почему выдает неправильный порядок, если months задан в виде словаря "months={}"?

months = {'январь', 'февраль', 'март', 'апрель', 'май', 'июнь', 'июль', 'август', 'сентябрь', 'октябрь', 'ноябрь', 'декабрь'}
print(months) 
>>> {'май', 'февраль', 'апрель', 'июль', 'сентябрь', 'январь', 'март', 'август', 'декабрь', 'июнь', 'октябрь', 'ноябрь'}
'''

#for m in months:
#  for d in days:
#    print(m,d,zodiak(m,d))
# Out:
# Введите месяц рождения: июнь
# Введите дату рождения: 25
# Ваш знак зодиака:  Рак
# '\n почему выдает неправильный порядок, если months задан в виде словаря "months={}"?\n\nmonths = {\'январь\', \'февраль\', \'март\', \'апрель\', \'май\', \'июнь\', \'июль\', \'август\', \'сентябрь\', \'октябрь\', \'ноябрь\', \'декабрь\'}\nprint(months) \n>>> {\'май\', \'февраль\', \'апрель\', \'июль\', \'сентябрь\', \'январь\', \'март\', \'август\', \'декабрь\', \'июнь\', \'октябрь\', \'ноябрь\'}\n'

# %% [markdown]
# #Задание 4

# %%
'''
Задание 4
Вам нужно написать программу для подбора упаковок по размерам товара. 
Размеры (ширина, длина, высота) хранятся в переменных (в сантиметрах):

Используйте следующие правила:
- если каждое из трех измерений менее или равно 15 сантиметрам, 
то выведите на экран "Коробка №1";
- если хотя бы одно из измерений больше 15 сантиметров, 
но менее 50 сантиметров, то выводите "Коробка №2";
- если длина товара больше 2 метров, то выводите "Упаковка для лыж";
во всех остальных случаях выводите "Стандартная коробка №3".
'''

dl = 200 #длина
sh = 200 #ширина
vys= 200 #высота

if dl>200 :
   print('Ищите упаковку для лыж')
elif ( dl<=15 and sh<=15 and vys<=15 ):
   print('Коробка №1')
elif ( dl<50 and sh<50 and vys<50 ) :
   print('Коробка №2')
else :
   print('Стандартная коробка №3')
# Out:
# Стандартная коробка №3

# %% [markdown]
# #Задание 5 (необязательное)

# %%
'''
Задание 5 (необязательное)
Дана переменная, в которой хранится шестизначное число 
(номер проездного билета). 
Напишите программу, которая будет определять, 
является ли данный билет "счастливым". 
Билет считается счастливым, если сумма первых трех цифр совпадает с 
суммой последних трех цифр номера.
'''

dano = '259466'

'''
str1 = dano[:3]
str2 = dano[3:]
print(str1,str2)
'''

a = int(dano[:3])
b = int(dano[3:])
#print(a,b)

sum_1 = a//100 + a//10%10 + a%10
#print(sum_1)
sum_2 = b//100 + b//10%10 + b%10
#print(sum_2)

if sum_1 == sum_2: 
   print('Счастливый билет')
else: 
   print('Несчастливый билет')
# Out:
# Счастливый билет

# %% [markdown]
# #Задание 6 (необязательное)

# %%
'''
Напишите программу, которая сможет вычислять площади трех фигур 
(круг, треугольник и прямоугольник). 
Тип фигуры запрашиваем через пользовательский ввод, 
после чего делаем запрос характеристик фигуры:

- если пользователь выбрал круг, запрашиваем его радиус,
- если треугольник – длины трех его сторон;
- если прямоугольник – длины двух его сторон.
'''

'''
Фо́рмула Герона для вычисления площади треугольника S по длинам его сторон a,b,c:
S=sqrt {p(p-a)(p-b)(p-c)},
где p — полупериметр треугольника:p=(a+b+c)/2.
'''

fig = str.lower(input('Введите тип фигуры: '))

if fig == 'круг':
   r = int(input('Введите радиус круга: '))
   print(' Площадь круга: ',(3.14159*(r**2)))
elif fig=='прямоугольник':
   a = int(input('Введите длину стороны A: '))
   b = int(input('Введите длину стороны B: '))
   print(' Площадь прямоугольника: ',(a*b))
elif fig=='треугольник':
   a = int(input('Введите длину стороны A: '))
   b = int(input('Введите длину стороны B: '))
   c = int(input('Введите длину стороны C: '))
   p = (a+b+c)/2
   s = (p*(p-a)*(p-b)*(p-c))**0.5
   print(' Площадь треугольника: ',s)
else: print('ошибка ввода')
# Out:
# Введите тип фигуры: крук
# ошибка ввода
