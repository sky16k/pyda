# %% [markdown]
# #Домашнее задание к лекции "Основы Python"

# %% [markdown]
# ##Преподаватель: Олег Булыгин
# #Домашнее задание к лекции "Управляющие конструкции и коллекции. Часть 1"
# Можно также найти домашнее задание здесь
# github.com...es_1.ipynb
#
# #Задание 1
# Дана переменная, в которой хранится слово из латинских букв. Напишите код, который выводит на экран:
# среднюю букву, если число букв в слове нечетное;две средних буквы, если число букв четное.
# Примеры работы программы:
# 1.word = 'test’
# Результат:
# es
# 1.word = 'testing’
# Результат:
# t
#
# ##Задание 2
# Напишите программу, которая последовательно запрашивает у пользователя числа (по одному за раз) и после первого нуля выводит сумму всех ранее введенных чисел.
# Примеры работы программы:
# Введите число:
# 1
# Введите число:
# 4
# Введите число:
# 6
# Введите число:
# 0
# Результат:
# 11
# Введите число:
# 0
# Результат:
# 0
#
# ##Задание 3
# Мы делаем MVP dating-сервиса, и у нас есть список парней и девушек.
# Выдвигаем гипотезу: лучшие рекомендации мы получим, если просто отсортируем имена по алфавиту и познакомим людей с одинаковыми индексами после сортировки! Но мы не будем никого знакомить, если кто-то может остаться без пары:
# Примеры работы программы:
# 1.
# boys = [‘Peter’, ‘Alex’, ‘John’, ‘Arthur’, ‘Richard’]
# girls = [‘Kate’, ‘Liza’, ‘Kira’, ‘Emma’, ‘Trisha’]
# Результат:
# Идеальные пары:
# Alex и Emma
# Arthur и Kate
# John и Kira
# Peter и Liza
# Richard и Trisha
# boys = [‘Peter’, ‘Alex’, ‘John’, ‘Arthur’, ‘Richard’, ‘Michael’]
# girls = [‘Kate’, ‘Liza’, ‘Kira’, ‘Emma’, ‘Trisha’]
# Результат:
# Внимание, кто-то может остаться без пары!
#
#
# ##Задание 4
# У нас есть список, содержащий информацию о среднедневной температуре в Фаренгейтах за произвольный период по странам (структура данных в примере). Необходимо написать код, который рассчитает среднюю температуру за период в Цельсиях(!) для каждой страны.
# Пример работы программы:
# countries_temperature = [
# [‘Thailand’, [75.2, 77, 78.8, 73.4, 68, 75.2, 77]],
# [‘Germany’, [57.2, 55.4, 59, 59, 53.6]],
# [‘Russia’, [35.6, 37.4, 39.2, 41, 42.8, 39.2, 35.6]],
# [‘Poland’, [50, 50, 53.6, 57.2, 55.4, 55.4]]
# ]
# Результат:
# Средняя температура в странах:
# Thailand - 23.9 С
# Germany - 13.8 С
# Russia - 3.7 С
# Poland - 12.0 С
#
#
# ##Задание 5 (необязательное)
# Дан поток логов по количеству просмотренных страниц для каждого пользователя. Вам необходимо написать алгоритм, который считает среднее значение просмотров на пользователя. Т. е. надо посчитать отношение суммы всех просмотров к количеству уникальных пользователей.
# Примеры работы программы:
# stream = [
# ‘2018-01-01,user1,3’,
# ‘2018-01-07,user1,4’,
# ‘2018-03-29,user1,1’,
# ‘2018-04-04,user1,13’,
# ‘2018-01-05,user2,7’,
# ‘2018-06-14,user3,4’,
# ‘2018-07-02,user3,10’,
# ‘2018-03-21,user4,19’,
# ‘2018-03-22,user4,4’,
# ‘2018-04-22,user4,8’,
# ‘2018-05-03,user4,9’,
# ‘2018-05-11,user4,11’,
# ]
# Результат:
# Среднее количество просмотров на уникального пользователя: 23.25
# stream = [
# ‘2018-01-01,user100,150’,
# ‘2018-01-07,user99,205’,
# ‘2018-03-29,user1001,81’
# ]
# Результат:
# Среднее количество просмотров на уникального пользователя: 145.33
#
#
# ##Задание 6 (необязательное)
# Необходимо у пользователя запрашивать набор чисел разделенных пробелом. В результате в отсортированном порядке должны выводиться числа, которые повторяются в вводе более одного раза.
# Примеры работы программы:
# 1.
# Введите числа:
# 4 8 0 3 4 2 0 3
# Результат:
# 0 3 4
# Введите числа:
# 1 1 2 2 3 3
# Результат:
# 1 2 3
# Введите числа:
# 10 15 15 103 200 200 200 1 1 1 1 1 2 2 2
# Результат:
# 1 2 15 200
#
#
#
# ##ПРИМЕЧАНИЕ
# Домашнее задание сдается ссылкой на блокнот в Google Colab или на репозиторий GitHub (только если знакомы с Git и устанавливали ПО).
# Не сможем проверить или помочь, если вы пришлете:
# файлы;архивы;скриншоты кода.
# Все обсуждения и консультации по выполнению домашнего задания ведутся только на соответствующем канале в slack.
# Как правильно задавать вопросы аспирантам, преподавателям и коллегам
# Прежде чем задать вопрос, попробуйте найти ответ в интернете. Навык самостоятельного поиска информации — один из важнейших. Каждый практикующий специалист любого уровня делает это ежедневно.
# Сформулируйте вопрос по алгоритму: 1) Что я делаю?
# 2) Какого результата я ожидаю?
# 3) Как фактический результат отличается от ожидаемого?
# 4) Что я уже попробовал сделать, чтобы исправить проблему?
# По возможности прикрепите к вопросу скриншоты либо ссылки на код. Не выкладывайте все решение, оставляйте только проблемный и воспроизводимый участок кода.
# Подготовьте решение к 4 августа 23:59
# Если не успеть — доступ к заданию и чату с экспертом будет закрыт.
# 🗓 Если не успеваете подготовить решение к 4 августа 23:59 — продлите дедлайн
# Решение
# |||
# Комментарий эксперту
# ​
# или прикрепите файл
# 0/25
# + Добавить
# Отправить на проверку
# Поделитесь впечатлениями от задания
# Вопросы по заданию
# Ваши вопросы увидят все — спрашивайте и получайте ответы от экспертов и одногруппников.
#
# Спросить
# ##Все вопросы

# %% [markdown]
# #Задание 1

# %%
первую задачу можно было даже записать в одну строку, вот так:
1
print(word[(len(word)-1)//2:(len(word)+2)//2])

# %%
'''

#Задание 1
Дана переменная, в которой хранится слово из латинских букв. Напишите код, который выводит на экран:

- среднюю букву, если число букв в слове нечетное;
- две средних буквы, если число букв четное.

'''

word = 'terufdaghjust'


if len(word)%2 == 0:
   print(word[(len(word)//2-1):(len(word)//2+1)])
else :
   print(word[len(word)//2])
# Out:
# a

# %%
word = 'terasaweqdjust'

print( word[ ((len(word)+1)//2 -1)  : ((len(word)//2) +1) ])
# Out:
# we

# %% [markdown]
# #Задание 2

# %%
# если интересно изучить итераторы, то посмотрите, как они помогли бы решить вторую задачу в 1 строку:
# 1
print(sum([int(x) for x in iter(input, '0')]))
# Out:
# 2
# 3
# 4
# 0
# 9

# %%
'''
#Задание 2
Напишите программу, которая последовательно запрашивает у пользователя числа (по одному за раз) и после первого нуля выводит сумму всех ранее введенных чисел.
'''
sum=0
null_flag = False

while not null_flag :
   num = int(input('Введите число: '))
   if num == 0 : null_flag = True
   else: sum += num
  
print(f'Сумма введенных чисел равна {sum}')
# Out:
# Введите число: 1
# Введите число: 2
# Введите число: 3
# Введите число: 4
# Введите число: 5
# Введите число: 6
# Введите число: 0
# Сумма введенных чисел равна 21

# %%
print('Сумма введенных чисел равна ', sum( [int(x) for x in iter(lambda : (input('Введите число: ')), '0') ] ))
# Out:
# Введите число: 1
# Введите число: 2
# Введите число: 3
# Введите число: 0
# Сумма введенных чисел равна  6

# %%
print('Сумма введенных чисел равна ', sum( [int(x) for x in iter( (input()), '0') ] ))
# Out:
# 3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-95220901a1a3> in <module>()
# ----> 1 print('Сумма введенных чисел равна ', sum( [int(x) for x in iter( (input()), '0') ] ))
#
# TypeError: iter(v, w): v must be callable

# %% [markdown]
# #Задание 3

# %%
'''
#Задание 3
Мы делаем MVP dating-сервиса, и у нас есть список парней и девушек.
Выдвигаем гипотезу: лучшие рекомендации мы получим, если просто отсортируем имена по алфавиту и познакомим людей с одинаковыми индексами после сортировки! Но мы не будем никого знакомить, если кто-то может остаться без пары:
Примеры работы программы:
1.
boys = [‘Peter’, ‘Alex’, ‘John’, ‘Arthur’, ‘Richard’]
girls = [‘Kate’, ‘Liza’, ‘Kira’, ‘Emma’, ‘Trisha’]
Результат:
Идеальные пары:
Alex и Emma
Arthur и Kate
John и Kira
Peter и Liza
Richard и Trisha
boys = [‘Peter’, ‘Alex’, ‘John’, ‘Arthur’, ‘Richard’, ‘Michael’]
girls = [‘Kate’, ‘Liza’, ‘Kira’, ‘Emma’, ‘Trisha’]
Результат:
Внимание, кто-то может остаться без пары!
'''

boys = ['Peter', 'Alex','John','Arthur','Richard','Michael']
girls = ['Kate','Liza','Kira','Emma','Trisha']

if len(boys) != len(girls) :
   print('Внимание, кто-то может остаться без пары!')
else:
#   for boy in boys : boy = boy.capitalize(), print(boy)
#   for girl in girls:girl= girl.capitalize(),print(girl)
   boys_s = sorted(boys)
   girls_s= sorted(girls)
#   print(boys_s)
#   print(girls_s)
   print('Идеальные пары:')
   for i in range(len(boys)) :
     print(f'{boys_s[i]} и {girls_s[i]}')
# Out:
# Внимание, кто-то может остаться без пары!

# %% [markdown]
# #Задание 4

# %%
в 4 задаче можно было обойтись без вложенного цикла, если использовать sum и len для всех расчетов:
1
2
3
for element in countries_temperature:
   avg_temp = sum(element[1]) / len(element[1])
   print(f"Средняя температура в {element[0]} - {round((avg_temp - 32)*5/9, 1)} C")

# %%
'''
Задание 4
У нас есть список, содержащий информацию о среднедневной температуре 
в Фаренгейтах за произвольный период по странам (структура данных в примере). 
Необходимо написать код, который рассчитает среднюю температуру за период 
в Цельсиях(!) для каждой страны.

Пример работы программы:

countries_temperature = [
[‘Thailand’, [75.2, 77, 78.8, 73.4, 68, 75.2, 77]],
[‘Germany’, [57.2, 55.4, 59, 59, 53.6]],
[‘Russia’, [35.6, 37.4, 39.2, 41, 42.8, 39.2, 35.6]],
[‘Poland’, [50, 50, 53.6, 57.2, 55.4, 55.4]]
]

Результат:

Средняя температура в странах:
Thailand - 23.9 С
Germany - 13.8 С
Russia - 3.7 С
Poland - 12.0 С
'''

'''
°C = (°F - 32) × 5/9
'''

import statistics as st

countries_temperature = [
['Thailand', [75.2, 77, 78.8, 73.4, 68, 75.2, 77]],
['Germany', [57.2, 55.4, 59, 59, 53.6]],
['Russia', [35.6, 37.4, 39.2, 41, 42.8, 39.2, 35.6]],
['Poland', [50, 50, 53.6, 57.2, 55.4, 55.4]]
]

print('Средняя температура в странах:')
for country in countries_temperature :
    t_sum = 0
    for t in country[1] : t_sum += t
#    print(t_sum)
#    t_mean = t_sum/len(country[1])
    t_mean_c = round( (( t_sum/len(country[1]) - 32)*5/9) ,1)
    print(country[0],' - ',t_mean_c,'°C')#round(st.mean(country[1]),1))
# Out:
# Средняя температура в странах:
# Thailand  -  23.9 °C
# Germany  -  13.8 °C
# Russia  -  3.7 °C
# Poland  -  12.0 °C

# %%
countries_temperature = [
['Thailand', [75.2, 77, 78.8, 73.4, 68, 75.2, 77]],
['Germany', [57.2, 55.4, 59, 59, 53.6]],
['Russia', [35.6, 37.4, 39.2, 41, 42.8, 39.2, 35.6]],
['Poland', [50, 50, 53.6, 57.2, 55.4, 55.4]]
]

print('Средняя температура в странах:')
for country in countries_temperature :
#     t_sum = 0
#     for t in country[1] : t_sum += t
# #    print(t_sum)
# #    t_mean = t_sum/len(country[1])
    t_mean = sum(country[1])/len(country[1])
#     t_mean_c = round( (( sum(country[1])/len(country[1]) - 32)*5/9) ,1)
    print(country[0],' - ', round( (( t_mean - 32)*5/9) ,1) ,'°C')
# Out:
# Средняя температура в странах:
# Thailand  -  23.9 °C
# Germany  -  13.8 °C
# Russia  -  3.7 °C
# Poland  -  12.0 °C

# %% [markdown]
# #Задание 5 (необязательное)

# %%
5 задачу можно было оптимизировать вот так при помощи list comprehension (вы как раз в следующем теоретическом блоке с этим знакомитесь):
1
2
3
4
total_views = sum([int(element.split(',')[2]) for element in stream])
no_of_users = len(set([element.split(',')[1] for element in stream]))

print("Среднее число просмотров на уникального пользователя:", round(total_views / no_of_users, 2))

# %%
'''
##Задание 5 (необязательное)
Дан поток логов по количеству просмотренных страниц для каждого пользователя. 
Вам необходимо написать алгоритм, который считает среднее значение просмотров 
на пользователя. Т. е. надо посчитать отношение суммы всех просмотров 
к количеству уникальных пользователей.

Примеры работы программы:
stream = [
‘2018-01-01,user1,3’,
‘2018-01-07,user1,4’,
‘2018-03-29,user1,1’,
‘2018-04-04,user1,13’,
‘2018-01-05,user2,7’,
‘2018-06-14,user3,4’,
‘2018-07-02,user3,10’,
‘2018-03-21,user4,19’,
‘2018-03-22,user4,4’,
‘2018-04-22,user4,8’,
‘2018-05-03,user4,9’,
‘2018-05-11,user4,11’,
]

Результат:
Среднее количество просмотров на уникального пользователя: 23.25

stream = [
‘2018-01-01,user100,150’,
‘2018-01-07,user99,205’,
‘2018-03-29,user1001,81’
]

Результат:
Среднее количество просмотров на уникального пользователя: 145.33
'''

'''
stream = [
'2018-01-01,user1,3',
'2018-01-07,user1,4',
'2018-03-29,user1,1',
'2018-04-04,user1,13',
'2018-01-05,user2,7',
'2018-06-14,user3,4',
'2018-07-02,user3,10',
'2018-03-21,user4,19',
'2018-03-22,user4,4',
'2018-04-22,user4,8',
'2018-05-03,user4,9',
'2018-05-11,user4,11',
]
'''

stream = [
'2018-01-01,user100,150',
'2018-01-07,user99,205',
'2018-03-29,user1001,81'
]

#logs = stream[0].split(',')
users = []
sum = 0

for log in stream:
#  print(logs.split(','))
    log = log.split(',')
    if log[1] not in users: 
       users.append(log[1])
    sum += int(log[2])   
'''
    print(log)
    print(log[0] )
    print(log[1])
    print(log[2])
    print(sum) 
    print(users)
    break
'''

print('Среднее количество просмотров на уникального пользователя: ', round( sum/ len(users) ,2) )
# Out:
# Среднее количество просмотров на уникального пользователя:  145.33

# %% [markdown]
# #Задание 6 (необязательное)

# %%
в 6 задаче можно было использовать join, чтобы все вывести не списком, а строкой, как в условии (предварительно преобразовав все обратно в строки).

# %%
'''
#Задание 6 (необязательное)
Необходимо у пользователя запрашивать набор чисел разделенных пробелом. В результате в отсортированном порядке должны выводиться числа, которые повторяются в вводе более одного раза.
Примеры работы программы:
1.
Введите числа:
4 8 0 3 4 2 0 3
Результат:
0 3 4
Введите числа:
1 1 2 2 3 3
Результат:
1 2 3
Введите числа:
10 15 15 103 200 200 200 1 1 1 1 1 2 2 2
Результат:
1 2 15 200
'''

'''
'''

#str = input('Введите числа через пробел: ')
str = input('Введите числа через пробел: ').split(' ')

num = [] #числа из строки
dub = [] #повторы

for s in str :
#    print(s)
    n = int(s)
    
    if ( (n in num) and 
         (n not in dub) ) :
       dub.append(n)      
 
    num.append(n)

print(sorted(dub))
# Out:
# Введите числа через пробел: 1 2 3 4 5 6 7 8 9 0 8 6 4 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-27151dc12e00> in <module>()
#      37     num.append(n)
#      38
# ---> 39 print(' '.join(sorted(dub) ) )
#
# TypeError: sequence item 0: expected str instance, int found

# %%
# str = input('Введите числа через пробел: ').split(' ')
str = '1 2 3 4 5 6 7 8 9 0 8 6 4 2'.split(' ')

num = [] #числа из строки
dub = [] #повторы

for s in str :
#    print(s)
#    n = int(s)
    
    if ( (s in num) and 
         (s not in dub) ) :
       dub.append(s)      
 
    num.append(s)

print(' '.join(sorted(dub)))
# Out:
# 2 4 6 8
