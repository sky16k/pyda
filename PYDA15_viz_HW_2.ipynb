# %% [markdown]
# <a href="https://colab.research.google.com/github/sky16k/pyda/blob/main/PYDA15_viz_HW_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

import os, sys
data_path = '/content/data'
try: 
    os.symlink('/content/drive/MyDrive/скул/DS/data', data_path)
    sys.path.insert(0,data_path)
except:
    pass
# Then you can install a library, and specify the target.
# !pip install --target=$data_path vk_api_config.py
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Домашнее задание

# %% [markdown]
# ## осн. текст

# %%
'''
Преподаватель: Олег Булыгин
Домашнее задание к лекции "Визуализация данных"

Обязательная часть
Вам необходимо провести базовый EDA (exploratory data analysis) выбранного набора данных.

Требования к анализу:

построить не менее 4 визуализаций различных видов;
каждая визуализация должным образом оформлена и читается даже в отрыве от контекста;
по каждой визуализации необходимо написать вывод (какую гипотезу на ее основе можно выдвинуть?).
Откуда брать данные?

Можете взять свои рабочие данные, либо найти открытые данные (например, на kaggle.com) по интересующей вас предметной области (тогда не забудьте приложить ссылку на данные). Если идей нет, можете взять один из перечисленных ниже:

данные приложений из Google Play;
данные о видео из трендов YouTube;
данные об уровне счастья в разных странах.

Дополнительная часть (необязательная)
построить дополнительно не менее 2 визуализаций (итого не менее 6);
в работе должны присутствовать следующие визуализации: boxplot, heatmap, scatter plot matrix;
'''
# Out:
# '\nПреподаватель: Олег Булыгин\nДомашнее задание к лекции "Визуализация данных"\n\nОбязательная часть\nВам необходимо провести базовый EDA (exploratory data analysis) выбранного набора данных.\n\nТребования к анализу:\n\nпостроить не менее 4 визуализаций различных видов;\nкаждая визуализация должным образом оформлена и читается даже в отрыве от контекста;\nпо каждой визуализации необходимо написать вывод (какую гипотезу на ее основе можно выдвинуть?).\nОткуда брать данные?\n\nМожете взять свои рабочие данные, либо найти открытые данные (например, на kaggle.com) по интересующей вас предметной области (тогда не забудьте приложить ссылку на данные). Если идей нет, можете взять один из перечисленных ниже:\n\nданные приложений из Google Play;\nданные о видео из трендов YouTube;\nданные об уровне счастья в разных странах.\n\nДополнительная часть (необязательная)\nпостроить дополнительно не менее 2 визуализаций (итого не менее 6);\nв работе должны присутствовать следующие визуализации: boxplot, heatmap, scatter plot matrix;\n'

# %% [markdown]
# ## Задание 1

# %% [markdown]
# ###текст

# %%
# комментарий эксперта
'''

'''
# Out:
# '\n\n'

# %%
'''
Обязательная часть
Вам необходимо провести базовый EDA (exploratory data analysis) выбранного набора данных.

Требования к анализу:

построить не менее 4 визуализаций различных видов;
каждая визуализация должным образом оформлена и читается даже в отрыве от контекста;
по каждой визуализации необходимо написать вывод (какую гипотезу на ее основе можно выдвинуть?).
Откуда брать данные?

Можете взять свои рабочие данные, либо найти открытые данные (например, на kaggle.com) по интересующей вас предметной области (тогда не забудьте приложить ссылку на данные). Если идей нет, можете взять один из перечисленных ниже:

данные приложений из Google Play;
данные о видео из трендов YouTube;
данные об уровне счастья в разных странах.

в работе должны присутствовать следующие визуализации: boxplot, heatmap, scatter plot matrix;

'''
# Out:
# '\nОбязательная часть\nВам необходимо провести базовый EDA (exploratory data analysis) выбранного набора данных.\n\nТребования к анализу:\n\nпостроить не менее 4 визуализаций различных видов;\nкаждая визуализация должным образом оформлена и читается даже в отрыве от контекста;\nпо каждой визуализации необходимо написать вывод (какую гипотезу на ее основе можно выдвинуть?).\nОткуда брать данные?\n\nМожете взять свои рабочие данные, либо найти открытые данные (например, на kaggle.com) по интересующей вас предметной области (тогда не забудьте приложить ссылку на данные). Если идей нет, можете взять один из перечисленных ниже:\n\nданные приложений из Google Play;\nданные о видео из трендов YouTube;\nданные об уровне счастья в разных странах.\n\nв работе должны присутствовать следующие визуализации: boxplot, heatmap, scatter plot matrix;\n\n'

# %% [markdown]
# ###программа

# %%
import pandas as pd
import numpy as np

# import re
from datetime import datetime, timedelta

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.cm as cm

import seaborn as sns

# %%
df = pd.read_csv('/content/data/RU_Electricity_Market_PZ_dayahead_price_volume.csv')
df
# Out:
#                timestep  consumption_eur  consumption_sib  price_eur  \
# 0      2006-09-01 00:00          62341.0          17916.0     275.22
# 1      2006-09-01 01:00          60625.0          17467.0       0.00
# 2      2006-09-01 02:00          59685.0          17161.0       0.00
# 3      2006-09-01 03:00          59500.0          17061.0       0.00
# 4      2006-09-01 04:00          60617.0          17074.0       0.00
# ...                 ...              ...              ...        ...
# 45811  2011-11-22 19:00         102893.0          24530.0     964.73
# 45812  2011-11-22 20:00         100380.0          23645.0     948.68
# 45813  2011-11-22 21:00          97864.0          23085.0     891.81
# 45814  2011-11-22 22:00          93982.0          22700.0     837.58
# 45815  2011-11-22 23:00          89567.0          22552.0     767.98
#
#        price_sib
# 0           0.00
# 1           0.00
# 2           0.00
# 3           0.00
# 4           0.00
# ...          ...
# 45811     568.85
# 45812     560.38
# 45813     552.50
# 45814     543.95
# 45815     540.60
#
# [45816 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45816 entries, 0 to 45815
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   timestep         45816 non-null  object
#  1   consumption_eur  45816 non-null  float64
#  2   consumption_sib  45816 non-null  float64
#  3   price_eur        45816 non-null  float64
#  4   price_sib        45816 non-null  float64
# dtypes: float64(4), object(1)
# memory usage: 1.7+ MB

# %%
df.describe()
# Out:
#        consumption_eur  consumption_sib     price_eur     price_sib
# count     45816.000000     45816.000000  45816.000000  45816.000000
# mean      82294.752037     22297.937294    730.232149    430.219400
# std       11046.135452      3035.991381    239.185651    167.183197
# min       57847.000000     15328.674800      0.000000      0.000000
# 25%       74157.500000     19697.000000    563.472500    365.077500
# 50%       81194.421875     22057.000000    708.590000    470.565000
# 75%       90337.886718     24788.054198    902.702500    533.752500
# max      111722.984400     30666.000000   2135.010000   1029.690000

# %%
# MWh
# RUB/MWh

# %% [markdown]
# несмотря на формальное отсутствие нечисловых значений, видно, что цена иногда принимает нулевые значения. скорее всего это и есть пропуски, стоит рассмотреть их природу и определить методы работы с ними

# %%
col_name = {'consumption_eur'	: 'потребление (евр), МВтч',
            'consumption_sib'	: 'потребление (сиб), МВтч',
            'price_eur'	: 'цена (евр), Р/МВтч',
            'price_sib' : 'цена (сиб), Р/МВтч',
            }

# %%
fig, axs =  plt.subplots(4)
fig.set_size_inches(6, 9)
plt.subplots_adjust(hspace=0.5)

for n,ax in enumerate(axs) :
    ax.plot(df.iloc[:,n+1])
    ax.set_title(col_name[ df.columns[n+1] ])

plt.show()

# %%
df[ (df['price_eur']==0) | (df['price_sib']==0) ].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1707 entries, 0 to 8139
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   timestep         1707 non-null   object
#  1   consumption_eur  1707 non-null   float64
#  2   consumption_sib  1707 non-null   float64
#  3   price_eur        1707 non-null   float64
#  4   price_sib        1707 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 80.0+ KB

# %%
df[ (df['price_eur']==0) ]
# Out:
#               timestep  consumption_eur  consumption_sib  price_eur  price_sib
# 1     2006-09-01 01:00          60625.0          17467.0        0.0       0.00
# 2     2006-09-01 02:00          59685.0          17161.0        0.0       0.00
# 3     2006-09-01 03:00          59500.0          17061.0        0.0       0.00
# 4     2006-09-01 04:00          60617.0          17074.0        0.0       0.00
# 26    2006-09-02 02:00          59588.0          17162.0        0.0       0.00
# 27    2006-09-02 03:00          59107.0          17056.0        0.0       0.00
# 28    2006-09-02 04:00          59100.0          17026.0        0.0       0.00
# 30    2006-09-02 06:00          60734.0          17224.0        0.0       0.00
# 48    2006-09-03 00:00          61034.0          17828.0        0.0       0.00
# 49    2006-09-03 01:00          59461.0          17419.0        0.0       0.00
# 50    2006-09-03 02:00          58351.0          17130.0        0.0       0.00
# 51    2006-09-03 03:00          57847.0          16980.0        0.0       0.00
# 52    2006-09-03 04:00          58300.0          16926.0        0.0       0.00
# 53    2006-09-03 05:00          58594.0          17007.0        0.0       0.00
# 54    2006-09-03 06:00          59289.0          17184.0        0.0       0.00
# 55    2006-09-03 07:00          59575.0          17415.0        0.0       0.00
# 56    2006-09-03 08:00          61790.0          17652.0        0.0       0.00
# 57    2006-09-03 09:00          63608.0          18066.0        0.0       0.00
# 73    2006-09-04 01:00          59967.0          17460.0        0.0       0.00
# 74    2006-09-04 02:00          59088.0          17169.0        0.0       0.00
# 75    2006-09-04 03:00          58853.0          17064.0        0.0       0.00
# 76    2006-09-04 04:00          59522.0          17173.0        0.0       0.00
# 96    2006-09-05 00:00          62896.0          18006.0        0.0       0.00
# 97    2006-09-05 01:00          61094.0          17590.0        0.0       0.00
# 98    2006-09-05 02:00          60307.0          17359.0        0.0       0.00
# 99    2006-09-05 03:00          59991.0          17111.0        0.0       0.00
# 100   2006-09-05 04:00          61226.0          17268.0        0.0       0.00
# 101   2006-09-05 05:00          62969.0          17467.0        0.0       0.00
# 120   2006-09-06 00:00          62764.0          18448.0        0.0       0.00
# 121   2006-09-06 01:00          61236.0          18034.0        0.0       0.00
# 122   2006-09-06 02:00          60359.0          17793.0        0.0       0.00
# 123   2006-09-06 03:00          60298.0          17625.0        0.0       0.00
# 124   2006-09-06 04:00          61200.0          17676.0        0.0       0.00
# 6506  2007-05-30 02:00          65586.0          17752.0        0.0       1.99
# 6507  2007-05-30 03:00          65219.0          17619.0        0.0       2.93
# 6508  2007-05-30 04:00          64804.0          17843.0        0.0       2.98

# %%
df.loc[:df[  (df['price_eur']==0) ].iloc[-1].name+1,:]
# 8139
# Out:
#               timestep  consumption_eur  consumption_sib  price_eur  price_sib
# 0     2006-09-01 00:00          62341.0          17916.0     275.22       0.00
# 1     2006-09-01 01:00          60625.0          17467.0       0.00       0.00
# 2     2006-09-01 02:00          59685.0          17161.0       0.00       0.00
# 3     2006-09-01 03:00          59500.0          17061.0       0.00       0.00
# 4     2006-09-01 04:00          60617.0          17074.0       0.00       0.00
# ...                ...              ...              ...        ...        ...
# 6505  2007-05-30 01:00          66256.0          18103.0     246.22       1.96
# 6506  2007-05-30 02:00          65586.0          17752.0       0.00       1.99
# 6507  2007-05-30 03:00          65219.0          17619.0       0.00       2.93
# 6508  2007-05-30 04:00          64804.0          17843.0       0.00       2.98
# 6509  2007-05-30 05:00          65795.0          18076.0     262.85      15.57
#
# [6510 rows x 5 columns]

# %%
df[  (df['price_sib']==0) ]
# Out:
#               timestep  consumption_eur  consumption_sib  price_eur  price_sib
# 0     2006-09-01 00:00          62341.0          17916.0     275.22        0.0
# 1     2006-09-01 01:00          60625.0          17467.0       0.00        0.0
# 2     2006-09-01 02:00          59685.0          17161.0       0.00        0.0
# 3     2006-09-01 03:00          59500.0          17061.0       0.00        0.0
# 4     2006-09-01 04:00          60617.0          17074.0       0.00        0.0
# ...                ...              ...              ...        ...        ...
# 6916  2007-06-16 04:00          60943.0          17409.0     301.27        0.0
# 8118  2007-08-05 06:00          62064.0          16710.0     471.97        0.0
# 8119  2007-08-05 07:00          62826.0          17008.0     469.74        0.0
# 8138  2007-08-06 02:00          62467.0          16800.0     558.43        0.0
# 8139  2007-08-06 03:00          62006.0          16747.0     554.00        0.0
#
# [1704 rows x 5 columns]

# %%
df.loc[:df[  (df['price_sib']==0) ].iloc[-1].name+1,:]
# 8139
# Out:
#               timestep  consumption_eur  consumption_sib  price_eur  price_sib
# 0     2006-09-01 00:00          62341.0          17916.0     275.22       0.00
# 1     2006-09-01 01:00          60625.0          17467.0       0.00       0.00
# 2     2006-09-01 02:00          59685.0          17161.0       0.00       0.00
# 3     2006-09-01 03:00          59500.0          17061.0       0.00       0.00
# 4     2006-09-01 04:00          60617.0          17074.0       0.00       0.00
# ...                ...              ...              ...        ...        ...
# 8136  2007-08-06 00:00          66089.0          17652.0     702.06     544.74
# 8137  2007-08-06 01:00          63938.0          17132.0     600.36     457.58
# 8138  2007-08-06 02:00          62467.0          16800.0     558.43       0.00
# 8139  2007-08-06 03:00          62006.0          16747.0     554.00       0.00
# 8140  2007-08-06 04:00          62357.0          16714.0     572.30     289.57
#
# [8141 rows x 5 columns]

# %%
1707/45816
# Out:
# 0.03725772655840754

# %% [markdown]
# хотя "пропущенных" значений не более 4% от общего числа, всё же мы имеем дело с временными рядами и монотонность данных может сыграть большую роль в анализе. к тому же видно, что изменение цены - процесс не внезапный. поэтому примем решение о заполнении нулевых значений методом интерполяции в соответствии со временем. а начальным значением примем модальное

# %%
last_null_id = df[  (df['price_sib']==0) ].iloc[-1].name
first_data_time = df.loc[last_null_id+1,'timestep']

# %%
df_fill = df.set_index('timestep').copy()
df_fill.index = pd.to_datetime(df_fill.index)
# df_fill.index
df_fill = df_fill.replace(0, np.NaN)
df_fill['price_sib'].iat[0] = df_fill['price_sib'].mode()
df_fill['price_sib'] = df_fill['price_sib'].interpolate(method="time")#.value_counts()
df_fill['price_eur'] = df_fill['price_eur'].interpolate(method="time")#.value_counts()
# df_fill.loc[:first_data_time, : ]

# %%
df_fill[ (df_fill['price_eur'].isna())  ]
# Out:
# Empty DataFrame
# Columns: [consumption_eur, consumption_sib, price_eur, price_sib]
# Index: []

# %%
df_fill.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 45816 entries, 2006-09-01 00:00:00 to 2011-11-22 23:00:00
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   consumption_eur  45816 non-null  float64
#  1   consumption_sib  45816 non-null  float64
#  2   price_eur        45816 non-null  float64
#  3   price_sib        45816 non-null  float64
# dtypes: float64(4)
# memory usage: 1.7 MB

# %%
df_fill.describe()
# Out:
#        consumption_eur  consumption_sib     price_eur     price_sib
# count     45816.000000     45816.000000  45816.000000  45816.000000
# mean      82294.752037     22297.937294    730.462280    434.569032
# std       11046.135452      3035.991381    238.638552    158.323675
# min       57847.000000     15328.674800      0.010000      0.010000
# 25%       74157.500000     19697.000000    563.472500    365.087500
# 50%       81194.421875     22057.000000    708.590000    470.565000
# 75%       90337.886718     24788.054198    902.702500    533.752500
# max      111722.984400     30666.000000   2135.010000   1029.690000

# %%
# копия для обработки
df_copy = df_fill.copy()

# %% [markdown]
# Посмотрим на распределение данных

# %%
fig, axs =  plt.subplots(4)
fig.set_size_inches(20, 12)
plt.subplots_adjust(hspace=0.3)

for n, col in enumerate(df_copy.columns) :
    axs[n].plot(df_copy[col])
    axs[n].set_title(f"{col_name[col]}, median={df_copy[col].median()}")

plt.show()

# %%
fig, axs =  plt.subplots(4)
fig.set_size_inches(6, 12)
plt.subplots_adjust(hspace=0.3)

for n, col in enumerate(df_copy.columns) :
    axs[n].hist(df_copy[col],bins=100)
    axs[n].set_title(f"{col_name[col]}, mode={df_copy[col].mode()[0]}")

plt.show()

# %%
fig, axs =  plt.subplots(1,4)
fig.set_size_inches(20, 6)
plt.subplots_adjust(wspace=0.5)

for n, col in enumerate(df_copy.columns) :
    axs[n].boxplot(df_copy[col])
    axs[n].set_title(f"{col_name[col]}, median={round(df_copy[col].median())}")

plt.show()

# %% [markdown]
# по приведенным графикам что-то определённое можно сказать только про потребление энергии:
# - имеется явная сезонная периодичность;
# - потребление европейской части гораздо выше сибирской;
# - разброс значений потребления европейской части тоже сильно выше как на коротких промежутках, так и между сезонами
# - судя по характеру нижней части графика, на коротких промежутках тоже может быть периодичность - следует рассмотреть подробнее
#
# про цену пока можно отметить лишь то, что:
# - в европейской части она, обычно, выше;
# - среди значений есть как необычно высокие, так и необычно низкие - возможно стоит применить обработку выбросов

# %% [markdown]
# для выявления зависимостей построим парные графики распределений

# %%
sns.pairplot(df_copy)

# %% [markdown]
# к сожалению, из-за наложения точек плохо видно состояние в самых плотных участках диаграмм. к тому же, некоторые сочетания на этой диаграмме бессмысленны. поэтому применим двухмерную гистограмму:

# %%
fig, axs = plt.subplots(4)
fig.set_size_inches(4, 16)
plt.subplots_adjust(hspace=0.3)

axs[0].hist2d(df_copy['consumption_eur'], df_copy['consumption_sib'], bins=(30,30))
axs[0].set_title("потребеление(сиб)/потребление(евр)")

axs[1].hist2d(df_copy['consumption_eur'], df_copy['price_eur'], bins=(30,30))
axs[1].set_title("цена(евр)/потребление(евр)")

axs[2].hist2d(df_copy['consumption_sib'], df_copy['price_sib'], bins=(30,30))
axs[2].set_title("цена(сиб)/потребеление(сиб)")

axs[3].hist2d(df_copy['price_eur'], df_copy['price_sib'], bins=(30,30))
axs[3].set_title("цена(сиб)/цена(евр)")

plt.show()

# %%
df_copy['year'] = df_copy.index.year
df_copy['month'] = df_copy.index.month
df_copy['day'] = df_copy.index.day
df_copy['hour'] = df_copy.index.hour

col_name['year']	= 'год'
col_name['month'] =	'месяц'
col_name['day']	  = 'дата'
col_name['hour']  = 'час'

# %%
df_copy
# Out:
#                      consumption_eur  consumption_sib  price_eur   price_sib  \
# timestep
# 2006-09-01 00:00:00          62341.0          17916.0    275.220    1.990000
# 2006-09-01 01:00:00          60625.0          17467.0    226.168    2.238088
# 2006-09-01 02:00:00          59685.0          17161.0    177.116    2.486176
# 2006-09-01 03:00:00          59500.0          17061.0    128.064    2.734265
# 2006-09-01 04:00:00          60617.0          17074.0     79.012    2.982353
# ...                              ...              ...        ...         ...
# 2011-11-22 19:00:00         102893.0          24530.0    964.730  568.850000
# 2011-11-22 20:00:00         100380.0          23645.0    948.680  560.380000
# 2011-11-22 21:00:00          97864.0          23085.0    891.810  552.500000
# 2011-11-22 22:00:00          93982.0          22700.0    837.580  543.950000
# 2011-11-22 23:00:00          89567.0          22552.0    767.980  540.600000
#
#                      year  month  day  hour
# timestep
# 2006-09-01 00:00:00  2006      9    1     0
# 2006-09-01 01:00:00  2006      9    1     1
# 2006-09-01 02:00:00  2006      9    1     2
# 2006-09-01 03:00:00  2006      9    1     3
# 2006-09-01 04:00:00  2006      9    1     4
# ...                   ...    ...  ...   ...
# 2011-11-22 19:00:00  2011     11   22    19
# 2011-11-22 20:00:00  2011     11   22    20
# 2011-11-22 21:00:00  2011     11   22    21
# 2011-11-22 22:00:00  2011     11   22    22
# 2011-11-22 23:00:00  2011     11   22    23
#
# [45816 rows x 8 columns]

# %% [markdown]
# а для комплексной оценки протяжённости возводимых линий создадим сводную таблицу и визуализируем её с помощью "heatmap"

# %%
fig, axs = plt.subplots(2,2)
fig.set_size_inches(16, 8)
plt.subplots_adjust(hspace=0.3)

for n,col in enumerate(list(df_fill.columns)) :
    df_map = (df_copy
              .pivot_table(
                 index='month',
                 columns='hour',
                 values=col,
                 aggfunc=np.median
                 )
              .fillna(0)
              .reindex(list(range(7,13))+list(range(1,7)))
              ) 
    
    axs.flat[n].set_title(col_name[col])
    g = sns.heatmap(df_map, ax=axs.flat[n])
    g.set_xlabel(col_name['hour'])
    g.set_ylabel(col_name['month'])
    # , col_name['month'], labelpad=10)
    
    # sns.set_theme(style="ticks", font_scale=1.25)
    # g = sns.relplot(
    #     data=penguins,
    #     x="bill_length_mm", y="bill_depth_mm", hue="body_mass_g",
    #     palette="crest", marker="x", s=100,
    # )
    # g.set_axis_labels("Bill length (mm)", "Bill depth (mm)", labelpad=10)
    # g.legend.set_title("Body mass (g)")
    # g.figure.set_size_inches(6.5, 4.5)
    # g.ax.margins(.15)
    # g.despine(trim=True)

plt.show()

# %% [markdown]
# подобрав периоды группировки можем подтвердить наглядно, что присутствует явная сезонность и дневная периодичность потребления. однако для цены периодичность имеет сложный характер, хотя и есть отчётливые области минимума и максимума с более чем двукратной разницей медианных значений. видимо в этом случае следует применять математические методы или разбить данные на несколько характерных групп.

# %%
df_map1 = (df_copy[ (2006 <= df_copy['year']) & (df_copy['year'] <= 2007) ]
              .pivot_table(
                 index='month',
                 columns='hour',
                 values='price_sib',
                 aggfunc=np.median
                 )
              # .fillna(0)
              # .reindex(list(range(7,13))+list(range(1,7)))
              ) 

df_map2 = (df_copy[ (2010 <= df_copy['year']) & (df_copy['year'] <= 2011) ]
              .pivot_table(
                 index='month',
                 columns='hour',
                 values='price_sib',
                 aggfunc=np.median
                 )
              # .fillna(0)
              # .reindex(list(range(7,13))+list(range(1,7)))
              ) 

df_map3 = (df_copy[ (2008 <= df_copy['year']) & (df_copy['year'] <= 2009) ]
              .pivot_table(
                 index='month',
                 columns='hour',
                 values='price_sib',
                 aggfunc=np.median
                 )
              # .fillna(0)
              # .reindex(list(range(7,13))+list(range(1,7)))
              ) 

df_map = (df_copy
              .pivot_table(
                 index='month',
                 columns='hour',
                 values='price_sib',
                 aggfunc=np.median
                 )
              # .fillna(0)
              # .reindex(list(range(7,13))+list(range(1,7)))
              ) 

fig, ax = plt.subplots()
fig.set_size_inches(16, 8)
# fig.suptitle('Axes values are scaled individually by default')
ax.set_title('наложение распределений медианных цен по группам по 2 года')

# sns.heatmap(df_map, ax=ax, coordinates = (-0.5, 23.5, 0.5, 12.5))

im = ax.imshow(df_map, 
               interpolation='none', 
               origin='lower',
               cmap='plasma', 
              #  cmap=cm.gray, 
               extent=(-0.5, 23.5, 0.5, 12.5)
               )

cs1 = ax.contour(list(df_map1.columns), 
                 list(df_map1.index), 
                 df_map1, 
                 6, 
                 linewidths=0.5, 
                 colors='k',
                 extent=(0, 23, 1, 12) 
                #  origin=None
                 )
cs2 = ax.contour(list(df_map2.columns), 
                 list(df_map2.index), 
                 df_map2, 
                 6, 
                 linewidths=0.5, 
                 colors='r', 
                 extent=(0, 23, 1, 12)
                #  origin='lower'
                 )
cs3 = ax.contour(list(df_map3.columns), 
                 list(df_map3.index), 
                 df_map3, 
                 6, 
                 linewidths=0.5, 
                 colors='b',
                 extent=(0, 23, 1, 12)
                 )

# l, b, w, h = cs1.get_position().bounds

ax.clabel(cs1, inline=True, fontsize=8)
ax.clabel(cs2, inline=True, fontsize=8)
ax.clabel(cs3, inline=True, fontsize=8)

black_patch = mpatches.Patch(color='black', label='2006-2007')
blue_patch = mpatches.Patch(color='blue', label='2008-2009')
red_patch = mpatches.Patch(color='red', label='2010-2011')

ax.set_xlabel(col_name['hour'])
ax.set_ylabel(col_name['month'])
ax.set_xticks(df_map.columns, minor=True)    
ax.set_yticks(df_map.index, minor=True)    

CBI = fig.colorbar(im, shrink=0.8)
# fig.colorbar(p2, ax=axs[1])

plt.legend(handles=[black_patch, blue_patch, red_patch])

# ax.legend([cs1, cs2, cs3], ['label1', 'label2', 'label3'])
# plt.legend([cs1, cs2, cs3], ['label1', 'label2', 'label3'], loc='upper right')
# plt.legend(labelcolor='linecolor')

# %% [markdown]
# разделение по 2 года, видимо, слишком крупное. видны некоторые расхождения в группах, но попробуем посмотреть более пристально.

# %%
fig, axs = plt.subplots(4,2)
fig.set_size_inches(16, 16)
plt.subplots_adjust(hspace=0.3)

df_map = (df_copy
              .pivot_table(
                 index='month',
                 columns='hour',
                 values='price_sib',
                 aggfunc=np.median
                 )
              # .fillna(0)
              # .reindex(list(range(7,13))+list(range(1,7)))
              ) 
axs[0,0].set_title(f'медианная цена за весь период наблюдений')
sns.heatmap(df_map, ax=axs[0,0])
axs[0,0].set_xlabel(col_name['hour'])
axs[0,0].set_ylabel(col_name['month'])
    

for n, year_ in enumerate(range(2006,2012) ) :
    df_map = (df_copy[ (df_copy['year'] == year_) ]
              .pivot_table(
                 index='month',
                 columns='hour',
                 values='price_sib',
                 aggfunc=np.median
                 )
              # .fillna(0)
              # .reindex(list(range(7,13))+list(range(1,7)))
              ) 

    axs.flat[n+2].set_title(f"{year_}")
    sns.heatmap(df_map, ax=axs.flat[n+2])

    axs.flat[n+2].set_xlabel(col_name['hour'])
    axs.flat[n+2].set_ylabel(col_name['month'])
    # axs.flat[n+2].set_xticks(df_map.columns, minor=True)    
    # axs.flat[n+2].set_yticks(df_map.index, minor=True)    

axs[0,1].set_visible(False)
fig.suptitle('Исследование периодичности цены в сибирской части', size= 'xx-large')
# print(type(axs[0,0]))
plt.show()

# %%
fig, axs = plt.subplots(4,2)
fig.set_size_inches(16, 16)
plt.subplots_adjust(hspace=0.3)

df_map = (df_copy
              .pivot_table(
                 index='month',
                 columns='hour',
                 values='price_eur',
                 aggfunc=np.median
                 )
              # .fillna(0)
              # .reindex(list(range(7,13))+list(range(1,7)))
              ) 
axs[0,0].set_title(f'медианная цена за весь период наблюдений')
sns.heatmap(df_map, ax=axs[0,0])
axs[0,0].set_xlabel(col_name['hour'])
axs[0,0].set_ylabel(col_name['month'])
    

for n, year_ in enumerate(range(2006,2012) ) :
    df_map = (df_copy[ (df_copy['year'] == year_) ]
              .pivot_table(
                 index='month',
                 columns='hour',
                 values='price_eur',
                 aggfunc=np.median
                 )
              # .fillna(0)
              # .reindex(list(range(7,13))+list(range(1,7)))
              ) 

    axs.flat[n+2].set_title(f"{year_}")
    sns.heatmap(df_map, ax=axs.flat[n+2])

    axs.flat[n+2].set_xlabel(col_name['hour'])
    axs.flat[n+2].set_ylabel(col_name['month'])
    # axs.flat[n+2].set_xticks(df_map.columns, minor=True)    
    # axs.flat[n+2].set_yticks(df_map.index, minor=True)    

axs[0,1].set_visible(False)
fig.suptitle('Исследование периодичности цены в европейской части', size= 'xx-large')
# print(type(axs[0,0]))
plt.show()

# %% [markdown]
# Так видны причины такой странной итоговой картины распределения. Но всё равно не ясно, почему возникли такие пики. Это стоит рассмотреть подробнее в большом исследовании, возможно с привлечением дополнительных данных.

# %%
я
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-e53f789fc313> in <module>
# ----> 1 я
#
# NameError: name 'я' is not defined

# %% [markdown]
# ## Задание 2

# %% [markdown]
# ###текст

# %%
# комментарий эксперта
'''

'''

# %%
'''
Дополнительная часть (необязательная)
построить дополнительно не менее 2 визуализаций (итого не менее 6);
в работе должны присутствовать следующие визуализации: boxplot, heatmap, scatter plot matrix;

'''

# %% [markdown]
# ###программа

# %%
import

# %% [markdown]
# #Теория: Визуализация данных

# %% [markdown]
# Булыгин Олег:
# * [LinkedIn](linkedin.com/in/obulygin)
# * [Мой канал в ТГ по Python](https://t.me/solidtalk)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
#увеличим дефолтный размер графиков
from pylab import rcParams
rcParams['figure.figsize'] = 11,7

# %% [markdown]
# ## <center> Matplotlib

# %% [markdown]
# Matplotlib – одна из самых популярных библиотек Python для визуализации данных.
#
# Импорт: import matplotlib.pyplot as plt
#
# Документация: https://matplotlib.org/contents.html

# %%
# первый позиционный аргумент – точки по X, второй – точки по Y. По умолчанию это единичные отрезки
plt.plot(15, 5, 'x')
# plt.show()

# %%
plt.plot([1, 4, 9, 12, 15, 20, 25])
# plt.show()
plt.plot([25, 20, 15, 12, 9, 4, 2])
# plt.show()

# %% [markdown]
# Поработаем с данными о продажах и оценках видеоигр с [Kaggle Datasets](https://www.kaggle.com/rush4ratio/video-game-sales-with-ratings).

# %%
df = pd.read_csv('https://raw.githubusercontent.com/obulygin/pyda_homeworks/master/stat_case_study/vgsales.csv')

# %%
print(df.shape)

# %%
df.head()

# %%
df.info()
# что видим?

# %%
# почему в User_Score object?
df['User_Score'].unique()

# %%
df['User_Score'] = df['User_Score'].replace('tbd', np.NaN)
df['User_Score'].unique()

# %%
# исправим типы данных
df['Year_of_Release'] = df['Year_of_Release'].astype('Int64')
df['User_Count'] = df['User_Count'].astype('Int64')
df['User_Score'] = df['User_Score'].astype('float64')
df['Critic_Count'] = df['Critic_Count'].astype('Int64')

# переводим оценки в один формат
df['User_Score'] = df['User_Score'] * 10

# %% [markdown]
# ### График
# Построим график динамики продаж видеоигр

# %%
dynamics_by_region = df[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Year_of_Release']] \
    .groupby('Year_of_Release').sum()
dynamics_by_region

# %%
# применяем функцию plot из matplotlib
# для каждой дополнительной настройки есть своя функция
plt.plot(dynamics_by_region.index, dynamics_by_region['Global_Sales'])
plt.title('Динамика продаж видеоигр')
plt.xlabel('Год')
plt.ylabel('Продажи, млн.')

# %%
# можем использовать цикл, чтобы построить графики для каждого региона
for region in dynamics_by_region.columns:
    plt.plot(dynamics_by_region.index, dynamics_by_region[region])

plt.title('Динамика продаж видеоигр')
plt.xlabel('Год')
plt.ylabel('Продажи, млн.') 
plt.legend(dynamics_by_region)

# %% [markdown]
# Метод .plot() в pandas основан на matplotlib. Если мы работаем с датафреймами, то это, как правило, более удобный вариант, чем использование matplotlib самой по себе. Мы сконцентрируемся на этом варианте.
#
# Документация: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.html

# %%
# если работает с табличными структурами, то можем воспользоваться функционалом, 
# встроенным в pandas. Так удобнее
# Метод plot по-умолчанию использует индекс датафрейма для оси X
# метод plot по-умолчанию строит график
dynamics_by_region['Global_Sales'].plot(title='Динамика продаж видеоигр',
                                        xlabel='Год', 
                                        ylabel='Продажи, млн.')

# %%
# plot без цикла построит графики для каждого региона (столбца)
# если у plot нету нужных методов, то можно применить функции matplotlib
dynamics_by_region.plot(title='Динамика продаж видеоигр', 
                             xlabel='Год', 
                             ylabel='Продажи, млн.')
plt.text(2007, 680, 'Почему отсюда начался спад?')  

plt.legend(loc='upper left')

# %% [markdown]
# ### Area chart

# %%
# по-умолчанию  Area chart всегда накопительный
dynamics_by_region.drop('Global_Sales', axis=1).plot(kind='area',
                             title='Динамика продаж видеоигр', 
                             xlabel='Год', 
                                stacked=False,
                             ylabel='Продажи, млн.')

# %% [markdown]
# ### Гистограммы

# %%
# распределение оценок пользователей
df['User_Score'].plot(kind='hist', 
                   title='Распределение оценок пользователей', bins=20)

# %%
# распределение оценок критиков
df['Critic_Score'].plot(kind='hist', 
                     title='Распределение оценок критиков', bins=20)

# %%
# сравнение
df['Critic_Score'].plot(kind='hist', 
                     alpha = 0.5,
                     bins=20,
                     density = True)


df['User_Score'].plot(kind='hist', 
                     alpha = 0.5,
                     bins=20,
                     density = True)
plt.legend(loc='upper left')
plt.title('Сравнение распределений оценок видеоигр')

# %% [markdown]
# ### Столбчатая диаграмма

# %%
# количество игр в разрезе платформ
games_by_platforms = df[['Name', 'Platform']].groupby('Platform').count()
games_by_platforms

# %%
games_by_platforms.loc[['PC', 'X360', 'PS3', 'PS4', 'XOne']].plot(kind='bar', 
                                                                  title='Топ 5 платформ по количеству и игр',
                                                                  xlabel='Платформа',
                                                                  ylabel='Количество игр')

# %%
# топ-5 жанров по продажам
top5_genres = df[['Global_Sales', 'Genre']].groupby('Genre').sum().sort_values('Global_Sales', ascending=False).head(5)
top5_genres.plot(kind='bar', title='Топ 5 жанров по продажам',
                             xlabel='Платформа',
                             ylabel='Количество игр')
for i, val in enumerate(top5_genres.values):
    plt.text(i, val, int(val), horizontalalignment='center', verticalalignment='bottom', fontdict={'size':14})

# %%
# динамика продаж в разрезе регионов. Выглядит фигово
dynamics_by_region.plot(kind='bar')

# %%
# Сделаем с накоплением!
dynamics_by_region.drop('Global_Sales', axis=1).plot(kind='bar', stacked=True)

# %% [markdown]
# ### Круговая диаграмма

# %%
# количество игр по платформам
pie_data = df['Platform'].value_counts()
pie_data.plot(kind='pie', title='Количество игр по платформам')

# %%
# количество игр по платформам (берем только топ-5)
top_platforms = df['Platform'].value_counts().head(5)
top_platforms.plot(kind='pie')
plt.legend(bbox_to_anchor=(0.6, .5, 0.5, 0.5))

# %% [markdown]
# ### Boxplot

# %%
# очень хорошо подходит для поиска выбросов!
df['User_Score'].plot(kind='box',
                   title='Распределение оценок пользователей', grid=True)

# %%
df[['User_Score', 'Critic_Score']].plot(kind='box',
                                        title='Распределение оценок', grid=True)

# %% [markdown]
# ### Точечная диаграмма

# %%
# посмотрим на взаимосвязь оценок и продаж
df.plot(kind='scatter', 
        x='User_Score', 
        y='Global_Sales', 
        title='Корреляция между продажами и оценками пользователей')
plt.ylim(0, 40)
df.plot(kind='scatter', 
        x='Critic_Score', 
        y='Global_Sales', 
        title='Корреляция между продажами и оценками критиков')
plt.ylim(0, 40)

# %%
# добавим третью ось
df.plot(kind='scatter', 
        x='User_Score', 
        y='Critic_Score', 
        s=df['Global_Sales']*20,
        title='Корреляция между оценкой критиков, пользоваталей и продажами'
       )

# %% [markdown]
# ## Стилизация таблиц

# %%
# выведем информацию о топ-10 издателях по продажам
top_developers_df = df.groupby('Developer')[['Global_Sales']].sum()\
    .sort_values('Global_Sales', ascending=False).head(10)
    
top_developers_df

# %%
top_developers_df.style.bar(align='mid')

# %% [markdown]
# ## <center> Seaborn

# %%
import seaborn as sns

# %%
# посмотрим зависимость продаж и оценок критиков
sns.regplot(data=df, x='Critic_Score', y='Global_Sales', color='green', marker='+')
plt.title('Корреляция между продажами и оценками критиков')
plt.ylim(0, 40)

# %% [markdown]
# C помощью `seaborn` можно построить достаточно сложные визуализации, которые были бы очень сложны для представления в коде при использовании `matplotlib`. Рассмотрим часть из них.

# %% [markdown]
# ### histplot

# %% [markdown]
# Посмотрим на **распределение оценок критиков `Critic_Score`**. Для этого построим __`histplot`__.

# %%
sns.histplot(df['Critic_Score'])
plt.title('Распределение оценок критиков')

# %% [markdown]
# ### joint_plot

# %% [markdown]
# Для того чтобы подробнее посмотреть на взаимосвязь двух численных признаков можно использовать __`joint_plot`__ – это гибрид `scatter plot` и `histogram`. Посмотрим на то, как связаны между собой **оценка критиков `Critic_Score` и оценка пользователя `User_Score`**.

# %%
sns.jointplot(x='Critic_Score', y='User_Score', data=df, kind='reg')

# %%
sns.jointplot(x='Critic_Score', y='User_Score', data=df, kind='reg', marginal_kws=dict(bins=10, fill=False))

# %% [markdown]
# ### scatter plot matrix

# %% [markdown]
# **pair plot (scatter plot matrix)** поможет нам посмотреть на одной картинке, как связаны между собой различные признаки в наборе данных

# %%
sns.pairplot(df)

# %%
sns.pairplot(df[['Global_Sales', 'Critic_Score', 'User_Score']])

# %% [markdown]
# ### boxplot

# %% [markdown]
# Давайте **сравним оценки критиков игр для топ-10 крупнейших игровых платформ** при помощи `boxplot`.

# %%
top_platforms = df['Platform'].value_counts().sort_values(ascending=False).head(10).index.values
# top_platforms
sns.boxplot(x="Platform", y="Critic_Score", 
            data=df[df['Platform'].isin(top_platforms)])

# %% [markdown]
# ### Heat map

# %% [markdown]
# `Heat map` позволяет посмотреть на распределение какого-то численного признака по двум категориальным. Визуализируем **суммарные продажи игр по жанрам и игровым платформам**.

# %%
platform_genre_sales = df[df['Platform'].isin(top_platforms)].pivot_table(
                        index='Platform', 
                        columns='Genre', 
                        values='Global_Sales', 
                        aggfunc=sum).fillna(0)

platform_genre_sales

# %%
sns.heatmap(platform_genre_sales, cmap='PuBu')

# %% [markdown]
# ## https://www.python-graph-gallery.com/

# %%
from plotly.offline import init_notebook_mode, iplot
import plotly
import plotly.graph_objs as go

data = []

for genre in df.Genre.unique():
    data.append(
        go.Box(y=df[df.Genre==genre].Critic_Score, 
               name=genre)
    )
iplot(data, show_link = False)

# %%
scores_genres_df = df.groupby('Genre')[['Critic_Score', 'User_Score']].mean()
sales_genres_df = df.groupby('Genre')[['Global_Sales']].sum()

genres_df = scores_genres_df.join(sales_genres_df)
    
genres_df.head()
trace0 = go.Scatter(
    x=genres_df.Critic_Score,
    y=genres_df.User_Score,
    mode = 'markers+text',
    text = genres_df.index,
    textposition='bottom center',
    marker = dict(
        size = 1/10*genres_df.Global_Sales,
        color = [
            'aqua', 'azure', 'beige', 'lightgreen',
            'lavender', 'lightblue', 'pink', 'salmon',
            'wheat', 'ivory', 'silver'
        ]
    )
)

data = [trace0]
layout = {
    'title': 'Statistics of video games genres',
    'xaxis': {'title': 'Critic Score'},
    'yaxis': {'title': 'User Score'}
}

fig = go.Figure(data=data, layout=layout)

iplot(fig, show_link=False)
